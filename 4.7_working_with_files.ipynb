# %%
#Print out every line in the file
with open('4.6_import_exercises.py') as f:
    file_contents = f.readline()

# %%
print(file_contents)
# Out:
# #!/usr/bin/env python

# %%
#Print out every line in the file, but add a line numbers
with open('4.6_import_exercises.py') as f:
    file_contents = f.readlines()
for i in range(len(file_contents)) :
    file_contents[i] = str(i) + ' ' + file_contents[i]
for line in file_contents:
    print(line)

#alternative way
# start = 1 is just i start at 1 but the line still start at first line
#for i, line in enumerate(file_contents,start =1):
    #print(i, line)
# Out:
# 0 #!/usr/bin/env python
#
# 1 # coding: utf-8
#
# 2
#
# 3 # Create a file named 4.6_import_exercises.py to do your work in.
#
# 4 #
#
# 5 # Import and test 3 of the functions from your functions exercise file.
#
# 6 #
#
# 7 # Your functions exercise are not currently in a file with a name that can be easily imported. Copy your functions exercise file and name the copy functions_exercises.py.
#
# 8 #
#
# 9 # Import each function in a different way:
#
# 10 #
#
# 11 # import the module and refer to the function with the . syntax
#
# 12 # use from to import the function directly
#
# 13 # use from and give the function a different name
#
# 14 # For the following exercises, read about and use the itertools module from the standard library to help you solve the problem.
#
# 15 #
#
# 16 # How many different ways can you combine the letters from "abc" with the numbers 1, 2, and 3?
#
# 17 # How many different ways can you combine two of the letters from "abcd"?
#
# 18 # Save this file as profiles.json inside of your exercises directory. Use the load function from the json module to open this file, it will produce a list of dictionaries. Using this data, write some code that calculates and outputs the following information:
#
# 19 #
#
# 20 # Total number of users
#
# 21 # Number of active users
#
# 22 # Number of inactive users
#
# 23 # Grand total of balances for all users
#
# 24 # Average balance per user
#
# 25 # User with the lowest balance
#
# 26 # User with the highest balance
#
# 27 # Most common favorite fruit
#
# 28 # Least most common favorite fruit
#
# 29 # Total number of unread messages for all users
#
# 30
#
# 31 # In[3]:
#
# 32
#
# 33
#
# 34 #Import and test 3 of the functions from your functions exercise file.
#
# 35
#
# 36 #Your functions exercise are not currently in a file with a name that can be easily imported.
#
# 37 #Copy your functions exercise file and name the copy functions_exercises.py.
#
# 38
#
# 39 #Import each function in a different way:
#
# 40
#
# 41     # import the module and refer to the function with the . syntax
#
# 42     # use from to import the function directly
#
# 43     # use from and give the function a different name
#
# 44
#
# 45
#
# 46 # In[76]:
#
# 47
#
# 48
#
# 49 # import the module and refer to the function with the . syntax
#
# 50 import functions_exercises
#
# 51 functions_exercises.calculate_tip(.2, 100)
#
# 52 calculate_tip(.1, 100)
#
# 53
#
# 54
#
# 55 # In[10]:
#
# 56
#
# 57
#
# 58 # use from to import the function directly
#
# 59 from functions_exercises import is_two as it
#
# 60 it
#
# 61
#
# 62
#
# 63 # In[12]:
#
# 64
#
# 65
#
# 66
#
# 67 from functions_exercises import col_index as ci
#
# 68 ci("AA")
#
# 69
#
# 70
#
# 71 # In[ ]:
#
# 72
#
# 73
#
# 74 #For the following exercises, read about and use the itertools module
#
# 75 #from the standard library to help you solve the problem.
#
# 76
#
# 77     #How many different ways can you combine the letters from "abc" with the numbers 1, 2, and 3?
#
# 78     #How many different ways can you combine two of the letters from "abcd"?
#
# 79
#
# 80
#
# 81 # In[36]:
#
# 82
#
# 83
#
# 84 #How many different ways can you combine the letters from "abc" with the numbers 1, 2, and 3?
#
# 85 from itertools import permutations
#
# 86 len(list(permutations("abc123", 6)))
#
# 87
#
# 88
#
# 89 # In[38]:
#
# 90
#
# 91
#
# 92 #How many different ways can you combine two of the letters from "abcd"?
#
# 93 from itertools import combinations
#
# 94 len(list(combinations("abcd", 2)))
#
# 95
#
# 96
#
# 97 # In[ ]:
#
# 98
#
# 99
#
# 100 #Save this file as profiles.json inside of your exercises directory.
#
# 101 #Use the load function from the json module to open this file,
#
# 102 #it will produce a list of dictionaries. Using this data,
#
# 103 #write some code that calculates and outputs the following information:
#
# 104     # Total number of users
#
# 105     # Number of active users
#
# 106     # Number of inactive users
#
# 107     # Grand total of balances for all users
#
# 108     # Average balance per user
#
# 109     # User with the lowest balance
#
# 110     # User with the highest balance
#
# 111     # Most common favorite fruit
#
# 112     # Least most common favorite fruit
#
# 113     # Total number of unread messages for all users
#
# 114
#
# 115
#
# 116 # In[45]:
#
# 117
#
# 118
#
# 119 import json
#
# 120 users = json.load(open("profiles.json"))
#
# 121 users
#
# 122
#
# 123
#
# 124 # In[65]:
#
# 125
#
# 126
#
# 127 # Total number of users
#
# 128 total_number_of_users = len(users)
#
# 129
#
# 130
#
# 131 # In[68]:
#
# 132
#
# 133
#
# 134 # Number of active users
#
# 135 number_of_active_users = len([user for user in users if user["isActive"] == True])
#
# 136
#
# 137
#
# 138 # In[69]:
#
# 139
#
# 140
#
# 141 # Number of inactive users
#
# 142 number_of_inactive_users = len([user for user in users if user["isActive"] == False])
#
# 143
#
# 144
#
# 145 # In[74]:
#
# 146
#
# 147
#
# 148 # Grand total of balances for all users
#
# 149 functions_exercises.handle_commas
#
# 150 # 1. remove $ sign 2.remove "," and change type to float
#
# 151 balance = [functions_exercises.handle_commas(user['balance'][1:]) for user in users]
#
# 152 total_balances = sum(balance)
#
# 153 total_balances
#
# 154
#
# 155
#
# 156 # In[70]:
#
# 157
#
# 158
#
# 159 #Average balance per user
#
# 160 average_balance = total_balances / total_number_of_users
#
# 161 average_balance
#
# 162
#
# 163
#
# 164 # In[81]:
#
# 165
#
# 166
#
# 167 # User with the lowest balance
#
# 168 lowest_balance = min(balance)
#
# 169 id_and_balance = [(user["index"],functions_exercises.handle_commas(user['balance'][1:])) for user in users]
#
# 170 for balance in id_and_balance:
#
# 171     if balance[1] == lowest_balance:
#
# 172         user_with_the_lowest_balance = balance[0]
#
# 173 user_with_the_lowest_balance
#
# 174
#
# 175
#
# 176 # In[85]:
#
# 177
#
# 178
#
# 179 #User with the highest balance
#
# 180 highest_balance = max(balance)
#
# 181 id_and_balance = [(user["index"],functions_exercises.handle_commas(user['balance'][1:])) for user in users]
#
# 182 for balance in id_and_balance:
#
# 183     if balance[1] == highest_balance:
#
# 184         user_with_the_highest_balance = balance[0]
#
# 185 user_with_the_highest_balance
#
# 186
#
# 187
#
# 188 # In[104]:
#
# 189
#
# 190
#
# 191 # Most common favorite fruit
#
# 192 fruits = [user['favoriteFruit'] for user in users ]
#
# 193 unique_fruits = list(set(fruits))
#
# 194 fruit_count = []
#
# 195 for u_f in unique_fruits:
#
# 196     n = 0
#
# 197     for fruit in fruits:
#
# 198         if u_f == fruit:
#
# 199             n = n +1
#
# 200     fruit_count.append((u_f, n))
#
# 201 fruit_count
#
# 202
#
# 203
#
# 204
#
# 205 # In[105]:
#
# 206
#
# 207
#
# 208 #Least most common favorite fruit
#
# 209 fruits = [user['favoriteFruit'] for user in users ]
#
# 210 unique_fruits = list(set(fruits))
#
# 211 fruit_count = []
#
# 212 for u_f in unique_fruits:
#
# 213     n = 0
#
# 214     for fruit in fruits:
#
# 215         if u_f == fruit:
#
# 216             n = n +1
#
# 217     fruit_count.append((u_f, n))
#
# 218 fruit_count
#
# 219
#
# 220
#
# 221 # In[133]:
#
# 222
#
# 223
#
# 224 # Total number of unread messages for all users
#
# 225 def remove_spaces(string):
#
# 226     return ''.join([c for c in string if c.isdigit()])
#
# 227 unread_messages_in_num = [int(remove_spaces(user["greeting"][-18: -20:-1][::-1])) for user in users ]
#
# 228 total_unread_messages = sum(unread_messages_in_num)
#
# 229 total_unread_messages
#
# 230
#
# 231
#
# 232 # In[ ]:
#
# 233
#
# 234
#
# 235
#
# 236
#
# 237
#
# 238 # In[ ]:
#
# 239
#
# 240
#
# 241
#
# 242

# %% [markdown]
# Create a variable named grocery_list. It should be a list, and the elements in the list should be a least 3 things that you need to buy from the grocery store.
#     Create a function named make_grocery_list. When run, this function should write the contents of the grocery_list variable to a file named my_grocery_list.txt.
#     Create a function named show_grocery_list. When run, it should read the items from the text file and show each item on the grocery list.
#     Create a function named buy_item. It should accept the name of an item on the grocery list, and remove that item from the list.

# %%
#Create a variable named grocery_list. 
#It should be a list,
#and the elements in the list should be a least 3 things that you need to buy from the grocery store.
grocery_list = ["fuse", "tape", "screw_driver"]

# %%
#Create a function named make_grocery_list. 
#When run, this function should write the contents of the grocery_list variable to a file named my_grocery_list.txt.
def make_grocery_list(grocery_list):
    with open('my_grocery_list.txt', 'w') as f:
        for item in grocery_list:
            f.write(item + "\n")
        
make_grocery_list(grocery_list)

# %%
#Create a function named show_grocery_list. 
#When run, it should read the items from the text file and show each item on the grocery list.
def show_grocery_list():
    with open("my_grocery_list.txt") as f:
        items = f.read()
    print(items)
show_grocery_list()
# Out:
# fuse
# tape
# screw_driver

# %%
#Create a function named buy_item. 
#It should accept the name of an item on the grocery list, and remove that item from the list.
def buy_item(item):
    grocery_list.remove(item)
    make_grocery_list(grocery_list)
    
buy_item("tape")

show_grocery_list()
# Out:
# fuse
# screw_driver
